# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2eW0uAeMK5xXwQXOy6Y3lQJUGsP_7hnFtYMUiZiuEaEBRb2hx" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt	    mohist-config    server-icon.png
# banned-players.json  forge.jar	    mohist.jar	     server.properties
# bukkit.yml	     forge.jar.log  ops.json	     spigot.yml
# colabconfig.json     help.yml	    permissions.yml  user_jvm_args.txt
# commands.yml	     libraries	    plugins	     usercache.json
# config		     logs	    run.bat	     usernamecache.json
# crash-reports	     mods	    run.sh	     whitelist.json
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:18831
# Estas jugando a minecraft: mohist en su version: 1.20.1
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 7246
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-643 but you have 1.20.1-580. The latest version has been built on 2024-04-01 01:15:46. You should update to fix recent bugs!
# Checking libraries, please wait...
# DownloadSource: MOHIST
# Download percentage:
#    0% [                                                    ] 0/5 (0:00:00 / ?)
# All libraries are nice :)!===========================] 5/5 (0:00:00 / 0:00:00)
# Searching incompatible mods...
# [01:56:21 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [01:56:21 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [01:56:21 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [01:56:21 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [01:56:22 INFO]: Found 50 dependencies adding them to mods collection
# [01:56:24 INFO]: Compatibility level set to JAVA_17
# [01:56:25 ERROR]: Mixin config fabric-item-group-api-v1.client.mixins.json does not specify "minVersion" property
# [01:56:25 INFO]: Propagating FML mod list to Fabric Loader
# [01:56:25 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [01:56:25 WARN]: Reference map 'naturalist-forge-forge-refmap.json' for naturalist.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:56:25 WARN]: Reference map 'simplyswords-common-refmap.json' for simplyswords-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:56:25 WARN]: Reference map 'simplyswords-forge-refmap.json' for simplyswords.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:56:25 INFO]: Loaded configuration file for Canary: 123 options available, 0 override(s) found
# [01:56:25 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:56:26 ERROR]: Attempted to load class net/minecraft/client/MouseHandler for invalid dist DEDICATED_SERVER
# [01:56:26 WARN]: Error loading class: net/minecraft/client/MouseHandler (java.lang.RuntimeException: Attempted to load class net/minecraft/client/MouseHandler for invalid dist DEDICATED_SERVER)
# [01:56:26 WARN]: @Mixin target net.minecraft.client.MouseHandler was not found fabric-screen-api-v1.mixins.json:MouseMixin
# [01:56:26 ERROR]: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER
# [01:56:26 WARN]: Error loading class: net/minecraft/client/gui/screens/Screen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER)
# [01:56:26 WARN]: @Mixin target net.minecraft.client.gui.screens.Screen was not found fabric-screen-api-v1.mixins.json:ScreenAccessor
# [01:56:31 WARN]: @Final field f_31427_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [01:56:31 WARN]: @Final field f_31428_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# t=2024-04-02T01:56:34+0000 lvl=warn msg="failed to open private leg" id=3209dc462428 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-04-02T01:56:35+0000 lvl=warn msg="failed to open private leg" id=37d8c19099f3 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [01:56:35 INFO]: Registered skill epicfight:epicfight:basic_attack
# [01:56:35 INFO]: Registered skill epicfight:epicfight:air_attack
# [01:56:35 INFO]: Registered skill epicfight:epicfight:roll
# [01:56:35 INFO]: Registered skill epicfight:epicfight:step
# [01:56:35 INFO]: Registered skill wom:wom:ender_step
# [01:56:35 INFO]: Registered skill epicfight:epicfight:knockdown_wakeup
# [01:56:35 INFO]: Registered skill wom:wom:ender_obscuris
# [01:56:35 INFO]: Registered skill wom:wom:dodge_master
# [01:56:35 INFO]: Registered skill epicfight:epicfight:guard
# [01:56:35 INFO]: Registered skill wom:wom:precise_roll
# [01:56:35 INFO]: Registered skill wom:wom:shadow_step
# [01:56:35 INFO]: Registered skill epicfight:epicfight:parrying
# [01:56:35 INFO]: Registered skill wom:wom:bull_charge
# [01:56:35 INFO]: Registered skill epicfight:epicfight:impact_guard
# [01:56:35 INFO]: Registered skill epicfight:epicfight:berserker
# [01:56:35 INFO]: Registered skill wom:wom:demon_mark_passive
# [01:56:35 INFO]: Registered skill epicfight:epicfight:death_harvest
# [01:56:35 INFO]: Registered skill wom:wom:torment_passive
# [01:56:35 INFO]: Registered skill epicfight:epicfight:emergency_escape
# [01:56:35 INFO]: Registered skill wom:wom:ruine_passive
# [01:56:35 INFO]: Registered skill epicfight:epicfight:endurance
# [01:56:35 INFO]: Registered skill wom:wom:lunar_echo_passive
# [01:56:35 INFO]: Registered skill epicfight:epicfight:forbidden_strength
# [01:56:35 INFO]: Registered skill wom:wom:satsujin_passive
# [01:56:35 INFO]: Registered skill epicfight:epicfight:hypervitality
# [01:56:35 INFO]: Registered skill epicfight:epicfight:stamina_pillager
# [01:56:35 INFO]: Registered skill wom:wom:solar_passive
# [01:56:35 INFO]: Registered skill wom:wom:charybdis
# [01:56:35 INFO]: Registered skill wom:wom:agony_plunge
# [01:56:35 INFO]: Registered skill epicfight:epicfight:swordmaster
# [01:56:35 INFO]: Registered skill epicfight:epicfight:technician
# [01:56:35 INFO]: Registered skill epicfight:epicfight:sweeping_edge
# [01:56:35 INFO]: Registered skill epicfight:epicfight:dancing_edge
# [01:56:35 INFO]: Registered skill epicfight:epicfight:the_guillotine
# [01:56:35 INFO]: Registered skill wom:wom:true_berserk
# [01:56:35 INFO]: Registered skill epicfight:epicfight:grasping_spire
# [01:56:35 INFO]: Registered skill wom:wom:plunder_perdition
# [01:56:35 INFO]: Registered skill epicfight:epicfight:heartpiercer
# [01:56:35 INFO]: Registered skill epicfight:epicfight:steel_whirlwind
# [01:56:35 INFO]: Registered skill wom:wom:sakura_state
# [01:56:35 INFO]: Registered skill epicfight:epicfight:battojutsu
# [01:56:35 INFO]: Registered skill epicfight:epicfight:battojutsu_passive
# [01:56:35 INFO]: Registered skill epicfight:epicfight:rushing_tempo
# [01:56:35 INFO]: Registered skill epicfight:epicfight:relentless_combo
# [01:56:35 INFO]: Registered skill wom:wom:ender_blast
# [01:56:35 INFO]: Registered skill epicfight:epicfight:liechtenauer
# [01:56:35 INFO]: Registered skill epicfight:epicfight:sharp_stab
# [01:56:35 INFO]: Registered skill epicfight:epicfight:eviscerate
# [01:56:35 INFO]: Registered skill wom:wom:ender_fusion
# [01:56:35 INFO]: Registered skill wom:wom:demonic_ascension
# [01:56:35 INFO]: Registered skill wom:wom:regierung
# [01:56:35 INFO]: Registered skill wom:wom:lunar_eclipse
# [01:56:35 INFO]: Registered skill wom:wom:solar_arcano
# [01:56:35 INFO]: Registered skill wom:wom:counter_attack
# [01:56:35 INFO]: Registered skill wom:wom:perfect_bulwark
# [01:56:35 INFO]: Registered skill wom:wom:vengeful_parry
# [01:56:35 INFO]: Registered skill wom:wom:arrow_tenacity
# [01:56:35 INFO]: Registered skill wom:wom:pain_anticipation
# [01:56:35 INFO]: Registered skill wom:wom:latent_retribution
# [01:56:35 INFO]: Registered skill epicfight:epicfight:blade_rush
# [01:56:35 INFO]: Registered skill wom:wom:vampirize
# [01:56:35 INFO]: Registered skill wom:wom:critical_knowledge
# [01:56:35 INFO]: Registered skill epicfight:epicfight:wrathful_lighting
# [01:56:35 INFO]: Registered skill epicfight:epicfight:tsunami
# [01:56:35 INFO]: Registered skill wom:wom:heart_shield
# [01:56:35 INFO]: Registered skill epicfight:epicfight:everlasting_allegiance
# [01:56:35 INFO]: Registered skill epicfight:epicfight:meteor_slam
# [01:56:35 INFO]: Registered skill wom:wom:mindset
# [01:56:35 INFO]: Registered skill wom:wom:adrenaline
# [01:56:35 INFO]: Registered skill epicfight:epicfight:revelation
# [01:56:35 INFO]: Registered skill epicfight:epicfight:demolition_leap
# [01:56:35 INFO]: Registered skill wom:wom:dancing_blade
# [01:56:35 INFO]: Registered skill epicfight:epicfight:phantom_ascent
# [01:56:35 INFO]: Registered skill wom:wom:meditation
# [01:56:35 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [01:56:35 INFO]: MinecraftForge v47.2.20 Initialized
# [01:56:35 INFO]: NeoForge v47.2.20 Initialized
# [01:56:36 INFO]: Mohist mod loading.....
# [01:56:36 INFO]: EventDispatcherRegistry initialized
# [01:56:36 INFO]: Kotlin For Forge Enabled!
# [01:56:37 INFO]: Registering C2S receiver with id architectury:sync_ids
# /workspaces/codespaces-jupyter/Minecraft-server/config
# [01:56:40 INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [01:56:40 INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [01:56:40 INFO]: Registered region regions_unexplored:primary to index 1 for type OVERWORLD
# [01:56:40 INFO]: Registered region regions_unexplored:secondary to index 2 for type OVERWORLD
# [01:56:40 INFO]: Registered region regions_unexplored:nether to index 1 for type NETHER
# [01:56:40 INFO]: Start animation registration of wom
# [01:56:40 INFO]: Assigned animation id 0 to biped/living/eating
# [01:56:40 INFO]: Assigned animation id 1 to biped/living/biped_hit_extra_long
# [01:56:40 INFO]: Assigned animation id 2 to biped/skill/kick
# [01:56:40 INFO]: Assigned animation id 3 to biped/skill/dodgemaster_back
# [01:56:40 INFO]: Assigned animation id 4 to biped/skill/dodgemaster_left
# [01:56:40 INFO]: Assigned animation id 5 to biped/skill/dodgemaster_right
# [01:56:40 INFO]: Assigned animation id 6 to biped/skill/enderstep_forward
# [01:56:40 INFO]: Assigned animation id 7 to biped/skill/enderstep_backward
# [01:56:40 INFO]: Assigned animation id 8 to biped/skill/enderstep_left
# [01:56:40 INFO]: Assigned animation id 9 to biped/skill/enderstep_right
# [01:56:40 INFO]: Assigned animation id 10 to biped/skill/ender_obscuris
# [01:56:40 INFO]: Assigned animation id 11 to biped/skill/mob_ender_obscuris
# [01:56:40 INFO]: Assigned animation id 12 to biped/skill/shadow_step_forward
# [01:56:40 INFO]: Assigned animation id 13 to biped/skill/shadow_step_backward
# [01:56:40 INFO]: Assigned animation id 14 to biped/skill/mob_shadow_step_forward
# [01:56:40 INFO]: Assigned animation id 15 to biped/skill/mob_shadow_step_backward
# [01:56:40 INFO]: Assigned animation id 16 to biped/skill/bull_charge
# [01:56:40 INFO]: Assigned animation id 17 to biped/skill/roll_forward
# [01:56:40 INFO]: Assigned animation id 18 to biped/skill/roll_backward
# [01:56:40 INFO]: Assigned animation id 19 to biped/skill/roll_left
# [01:56:40 INFO]: Assigned animation id 20 to biped/skill/roll_right
# [01:56:40 INFO]: Assigned animation id 21 to biped/skill/meditation_siting
# [01:56:40 INFO]: Assigned animation id 22 to biped/skill/meditation_breathing
# [01:56:40 INFO]: Assigned animation id 23 to biped/combat/agony_auto_1
# [01:56:40 INFO]: Assigned animation id 24 to biped/combat/agony_auto_2
# [01:56:40 INFO]: Assigned animation id 25 to biped/combat/agony_auto_3
# [01:56:40 INFO]: Assigned animation id 26 to biped/combat/agony_auto_4
# [01:56:40 INFO]: Assigned animation id 27 to biped/combat/agony_clawstrike
# [01:56:40 INFO]: Assigned animation id 28 to biped/combat/agony_counter
# [01:56:40 INFO]: Assigned animation id 29 to biped/combat/agony_airslash
# [01:56:40 INFO]: Assigned animation id 30 to biped/living/agony_idle
# [01:56:40 INFO]: Assigned animation id 31 to biped/living/agony_run
# [01:56:40 INFO]: Assigned animation id 32 to biped/living/agony_walk
# [01:56:40 INFO]: Assigned animation id 33 to biped/skill/agony_guard
# [01:56:40 INFO]: Assigned animation id 34 to biped/skill/agony_guard_hit1
# [01:56:40 INFO]: Assigned animation id 35 to biped/skill/agony_guard_hit2
# [01:56:40 INFO]: Assigned animation id 36 to biped/skill/agony_plunge_forward
# [01:56:40 INFO]: Assigned animation id 37 to biped/skill/agony_plunge_forward_x
# [01:56:40 INFO]: Assigned animation id 38 to biped/combat/ruine_auto_1
# [01:56:40 INFO]: Assigned animation id 39 to biped/combat/ruine_auto_2
# [01:56:40 INFO]: Assigned animation id 40 to biped/combat/ruine_auto_3
# [01:56:40 INFO]: Assigned animation id 41 to biped/combat/ruine_auto_4
# [01:56:40 INFO]: Assigned animation id 42 to biped/skill/ruine_counterattack
# [01:56:40 INFO]: Assigned animation id 43 to biped/combat/ruine_dash
# [01:56:40 INFO]: Assigned animation id 44 to biped/combat/ruine_comet
# [01:56:40 INFO]: Assigned animation id 45 to biped/skill/ruine_block
# [01:56:40 INFO]: Assigned animation id 46 to biped/living/ruine_idle
# [01:56:40 INFO]: Assigned animation id 47 to biped/living/ruine_boosted_idle
# [01:56:40 INFO]: Assigned animation id 48 to biped/living/ruine_run
# [01:56:40 INFO]: Assigned animation id 49 to biped/living/ruine_walk
# [01:56:40 INFO]: Assigned animation id 50 to biped/living/ruine_boosted_walk
# [01:56:40 INFO]: Assigned animation id 51 to biped/skill/ruine_plunder
# [01:56:40 INFO]: Assigned animation id 52 to biped/skill/ruine_expiation
# [01:56:40 INFO]: Assigned animation id 53 to biped/skill/ruine_redemption
# [01:56:40 INFO]: Assigned animation id 54 to biped/combat/torment_auto_1
# [01:56:40 INFO]: Assigned animation id 55 to biped/combat/torment_auto_2
# [01:56:40 INFO]: Assigned animation id 56 to biped/combat/torment_auto_3
# [01:56:40 INFO]: Assigned animation id 57 to biped/combat/torment_auto_4
# [01:56:40 INFO]: Assigned animation id 58 to biped/combat/torment_dash
# [01:56:40 INFO]: Assigned animation id 59 to biped/combat/torment_airslam
# [01:56:40 INFO]: Assigned animation id 60 to biped/living/torment_idle
# [01:56:40 INFO]: Assigned animation id 61 to biped/living/torment_run
# [01:56:40 INFO]: Assigned animation id 62 to biped/living/torment_walk
# [01:56:40 INFO]: Assigned animation id 63 to biped/living/torment_charge
# [01:56:40 INFO]: Assigned animation id 64 to biped/combat/torment_charged_attack_1
# [01:56:40 INFO]: Assigned animation id 65 to biped/combat/torment_charged_attack_2
# [01:56:40 INFO]: Assigned animation id 66 to biped/combat/torment_charged_attack_3
# [01:56:40 INFO]: Assigned animation id 67 to biped/living/torment_berserk_idle
# [01:56:40 INFO]: Assigned animation id 68 to biped/skill/torment_berserk_auto_1
# [01:56:40 INFO]: Assigned animation id 69 to biped/skill/torment_berserk_auto_2
# [01:56:40 INFO]: Assigned animation id 70 to biped/skill/torment_berserk_dash
# [01:56:40 INFO]: Assigned animation id 71 to biped/skill/torment_berserk_airslam
# [01:56:40 INFO]: Assigned animation id 72 to biped/skill/torment_berserk_convert
# [01:56:40 INFO]: Assigned animation id 73 to biped/living/torment_berserk_run
# [01:56:40 INFO]: Assigned animation id 74 to biped/living/torment_berserk_walk
# [01:56:40 INFO]: Assigned animation id 75 to biped/combat/katana_sheathed_auto_1
# [01:56:40 INFO]: Assigned animation id 76 to biped/combat/katana_sheathed_auto_2
# [01:56:40 INFO]: Assigned animation id 77 to biped/combat/katana_sheathed_auto_3
# [01:56:40 INFO]: Assigned animation id 78 to biped/combat/katana_sheathed_dash
# [01:56:40 INFO]: Assigned animation id 79 to biped/combat/katana_sheathed_dash
# [01:56:40 INFO]: Assigned animation id 80 to biped/combat/katana_sheathed_counter
# [01:56:40 INFO]: Assigned animation id 81 to biped/living/katana_sheathe
# [01:56:40 INFO]: Assigned animation id 82 to biped/living/katana_sheathed_idle
# [01:56:40 INFO]: Assigned animation id 83 to biped/living/katana_sheathed_run
# [01:56:40 INFO]: Assigned animation id 84 to biped/combat/katana_auto_1
# [01:56:40 INFO]: Assigned animation id 85 to biped/combat/katana_auto_2
# [01:56:40 INFO]: Assigned animation id 86 to biped/combat/katana_auto_3
# [01:56:40 INFO]: Assigned animation id 87 to biped/combat/katana_dash
# [01:56:40 INFO]: Assigned animation id 88 to biped/combat/katana_tsukuyomi
# [01:56:40 INFO]: Assigned animation id 89 to biped/living/katana_idle
# [01:56:40 INFO]: Assigned animation id 90 to biped/living/katana_walk
# [01:56:40 INFO]: Assigned animation id 91 to biped/living/katana_run
# [01:56:40 INFO]: Assigned animation id 92 to biped/skill/katana_guard
# [01:56:40 INFO]: Assigned animation id 93 to biped/skill/katana_guard_hit
# [01:56:40 INFO]: Assigned animation id 94 to biped/skill/katana_fatal_draw
# [01:56:40 INFO]: Assigned animation id 95 to biped/skill/katana_fatal_draw_second
# [01:56:40 INFO]: Assigned animation id 96 to biped/skill/katana_fatal_draw_dash
# [01:56:40 INFO]: Assigned animation id 97 to biped/skill/katana_sakura_timed_slash
# [01:56:40 INFO]: Assigned animation id 98 to biped/combat/enderblaster_onehand_auto_1
# [01:56:40 INFO]: Assigned animation id 99 to biped/combat/enderblaster_onehand_auto_2
# [01:56:40 INFO]: Assigned animation id 100 to biped/combat/enderblaster_onehand_auto_3
# [01:56:40 INFO]: Assigned animation id 101 to biped/combat/enderblaster_onehand_auto_4
# [01:56:40 INFO]: Assigned animation id 102 to biped/combat/enderblaster_onehand_dash
# [01:56:40 INFO]: Assigned animation id 103 to biped/combat/enderblaster_onehand_jumpkick
# [01:56:40 INFO]: Assigned animation id 104 to biped/skill/enderblaster_onehand_shoot_1
# [01:56:40 INFO]: Assigned animation id 105 to biped/skill/enderblaster_onehand_shoot_2
# [01:56:40 INFO]: Assigned animation id 106 to biped/skill/enderblaster_onehand_shoot_2_forward
# [01:56:40 INFO]: Assigned animation id 107 to biped/skill/enderblaster_onehand_shoot_2_left
# [01:56:40 INFO]: Assigned animation id 108 to biped/skill/enderblaster_onehand_shoot_2_right
# [01:56:40 INFO]: Assigned animation id 109 to biped/skill/enderblaster_onehand_shoot_3
# [01:56:40 INFO]: Assigned animation id 110 to biped/skill/enderblaster_onehand_airshoot
# [01:56:40 INFO]: Assigned animation id 111 to biped/skill/enderblaster_onehand_shoot_dash
# [01:56:40 INFO]: Assigned animation id 112 to biped/living/enderblaster_onehand_idle
# [01:56:40 INFO]: Assigned animation id 113 to biped/living/enderblaster_onehand_walk
# [01:56:40 INFO]: Assigned animation id 114 to biped/living/enderblaster_onehand_run
# [01:56:40 INFO]: Assigned animation id 115 to biped/skill/enderblaster_onehand_aiming
# [01:56:40 INFO]: Assigned animation id 116 to biped/skill/enderblaster_onehand_shoot
# [01:56:40 INFO]: Assigned animation id 117 to biped/skill/enderblaster_onehand_shoot_layed
# [01:56:40 INFO]: Assigned animation id 118 to biped/skill/enderblaster_onehand_reload
# [01:56:40 INFO]: Assigned animation id 119 to biped/combat/enderblaster_onehand_auto_1
# [01:56:40 INFO]: Assigned animation id 120 to biped/combat/enderblaster_onehand_auto_2
# [01:56:40 INFO]: Assigned animation id 121 to biped/combat/enderblaster_onehand_auto_3
# [01:56:40 INFO]: Assigned animation id 122 to biped/combat/enderblaster_onehand_auto_4
# [01:56:40 INFO]: Assigned animation id 123 to biped/combat/enderblaster_twohand_tishnaw
# [01:56:40 INFO]: Assigned animation id 124 to biped/combat/enderblaster_twohand_dash
# [01:56:40 INFO]: Assigned animation id 125 to biped/skill/enderblaster_twohand_shoot_1
# [01:56:40 INFO]: Assigned animation id 126 to biped/skill/enderblaster_twohand_shoot_2
# [01:56:40 INFO]: Assigned animation id 127 to biped/skill/enderblaster_twohand_shoot_3
# [01:56:40 INFO]: Assigned animation id 128 to biped/skill/enderblaster_twohand_shoot_4
# [01:56:40 INFO]: Assigned animation id 129 to biped/skill/enderblaster_twohand_evade_left
# [01:56:40 INFO]: Assigned animation id 130 to biped/skill/enderblaster_twohand_evade_right
# [01:56:40 INFO]: Assigned animation id 131 to biped/skill/enderblaster_twohand_airshoot
# [01:56:40 INFO]: Assigned animation id 132 to biped/skill/enderblaster_twohand_shoot_dash
# [01:56:40 INFO]: Assigned animation id 133 to biped/living/enderblaster_twohand_idle
# [01:56:40 INFO]: Assigned animation id 134 to biped/living/enderblaster_twohand_walk
# [01:56:40 INFO]: Assigned animation id 135 to biped/skill/enderblaster_twohand_aiming
# [01:56:40 INFO]: Assigned animation id 136 to biped/skill/enderblaster_twohand_shoot_right
# [01:56:40 INFO]: Assigned animation id 137 to biped/skill/enderblaster_twohand_shoot_left
# [01:56:40 INFO]: Assigned animation id 138 to biped/skill/enderblaster_twohand_shoot_layed_right
# [01:56:40 INFO]: Assigned animation id 139 to biped/skill/enderblaster_twohand_shoot_layed_left
# [01:56:40 INFO]: Assigned animation id 140 to biped/skill/enderblaster_twohand_reload
# [01:56:40 INFO]: Assigned animation id 141 to biped/combat/staff_auto_1
# [01:56:40 INFO]: Assigned animation id 142 to biped/combat/staff_auto_2
# [01:56:40 INFO]: Assigned animation id 143 to biped/combat/staff_auto_3
# [01:56:40 INFO]: Assigned animation id 144 to biped/combat/staff_dash
# [01:56:40 INFO]: Assigned animation id 145 to biped/combat/staff_kingkong
# [01:56:40 INFO]: Assigned animation id 146 to biped/skill/staff_charybdisandscylla
# [01:56:40 INFO]: Assigned animation id 147 to biped/living/staff_idle
# [01:56:40 INFO]: Assigned animation id 148 to biped/living/staff_run
# [01:56:40 INFO]: Assigned animation id 149 to biped/combat/antitheus_agression
# [01:56:40 INFO]: Assigned animation id 150 to biped/combat/antitheus_guillotine
# [01:56:40 INFO]: Assigned animation id 151 to biped/combat/antitheus_auto_1
# [01:56:40 INFO]: Assigned animation id 152 to biped/combat/antitheus_auto_2
# [01:56:40 INFO]: Assigned animation id 153 to biped/combat/antitheus_auto_3
# [01:56:40 INFO]: Assigned animation id 154 to biped/combat/antitheus_auto_4
# [01:56:40 INFO]: Assigned animation id 155 to biped/living/antitheus_idle
# [01:56:40 INFO]: Assigned animation id 156 to biped/living/antitheus_run
# [01:56:40 INFO]: Assigned animation id 157 to biped/living/antitheus_walk
# [01:56:40 INFO]: Assigned animation id 158 to biped/skill/antitheus_aiming
# [01:56:40 INFO]: Assigned animation id 159 to biped/skill/antitheus_shoot
# [01:56:40 INFO]: Assigned animation id 160 to biped/skill/antitheus_pull
# [01:56:40 INFO]: Assigned animation id 161 to biped/skill/antitheus_ascension
# [01:56:40 INFO]: Assigned animation id 162 to biped/skill/antitheus_lapse
# [01:56:40 INFO]: Assigned animation id 163 to biped/skill/antitheus_ascended_auto_1
# [01:56:40 INFO]: Assigned animation id 164 to biped/skill/antitheus_ascended_auto_2
# [01:56:40 INFO]: Assigned animation id 165 to biped/skill/antitheus_ascended_auto_3
# [01:56:40 INFO]: Assigned animation id 166 to biped/skill/antitheus_ascended_deathfall
# [01:56:40 INFO]: Assigned animation id 167 to biped/skill/antitheus_ascended_blink
# [01:56:40 INFO]: Assigned animation id 168 to biped/skill/antitheus_ascended_blackhole
# [01:56:40 INFO]: Assigned animation id 169 to biped/living/antitheus_ascended_idle
# [01:56:40 INFO]: Assigned animation id 170 to biped/living/antitheus_ascended_run
# [01:56:40 INFO]: Assigned animation id 171 to biped/living/antitheus_ascended_walk
# [01:56:40 INFO]: Assigned animation id 172 to biped/living/herrscher_idle
# [01:56:40 INFO]: Assigned animation id 173 to biped/living/herrscher_walk
# [01:56:40 INFO]: Assigned animation id 174 to biped/living/herrscher_run
# [01:56:40 INFO]: Assigned animation id 175 to biped/skill/herrscher_guard
# [01:56:40 INFO]: Assigned animation id 176 to biped/skill/herrscher_guard_hit
# [01:56:40 INFO]: Assigned animation id 177 to biped/skill/herrscher_guard_parry
# [01:56:40 INFO]: Assigned animation id 178 to biped/skill/herrscher_trane
# [01:56:40 INFO]: Assigned animation id 179 to biped/combat/herrscher_auto_1
# [01:56:40 INFO]: Assigned animation id 180 to biped/combat/herrscher_auto_2
# [01:56:40 INFO]: Assigned animation id 181 to biped/combat/herrscher_auto_3
# [01:56:40 INFO]: Assigned animation id 182 to biped/combat/herrscher_befreiung
# [01:56:40 INFO]: Assigned animation id 183 to biped/combat/herrscher_ausrottung
# [01:56:40 INFO]: Assigned animation id 184 to biped/skill/gezets_auto_1
# [01:56:40 INFO]: Assigned animation id 185 to biped/skill/gezets_auto_2
# [01:56:40 INFO]: Assigned animation id 186 to biped/skill/gezets_auto_3
# [01:56:40 INFO]: Assigned animation id 187 to biped/skill/gezets_sprengkopf
# [01:56:40 INFO]: Assigned animation id 188 to biped/skill/gezets_krummen
# [01:56:40 INFO]: Assigned animation id 189 to biped/living/moonless_idle
# [01:56:40 INFO]: Assigned animation id 190 to biped/living/moonless_walk
# [01:56:40 INFO]: Assigned animation id 191 to biped/living/moonless_run
# [01:56:40 INFO]: Assigned animation id 192 to biped/combat/moonless_reversed_bypass
# [01:56:40 INFO]: Assigned animation id 193 to biped/combat/moonless_bypass
# [01:56:40 INFO]: Assigned animation id 194 to biped/combat/moonless_auto_1
# [01:56:40 INFO]: Assigned animation id 195 to biped/combat/moonless_auto_2
# [01:56:40 INFO]: Assigned animation id 196 to biped/combat/moonless_auto_3
# [01:56:40 INFO]: Assigned animation id 197 to biped/combat/moonless_auto_1_verso
# [01:56:40 INFO]: Assigned animation id 198 to biped/combat/moonless_auto_2_verso
# [01:56:40 INFO]: Assigned animation id 199 to biped/combat/moonless_auto_3_verso
# [01:56:40 INFO]: Assigned animation id 200 to biped/skill/moonless_lunar_echo
# [01:56:40 INFO]: Assigned animation id 201 to biped/skill/moonless_lunar_eclipse
# [01:56:40 INFO]: Assigned animation id 202 to biped/combat/moonless_crescent
# [01:56:40 INFO]: Assigned animation id 203 to biped/combat/moonless_fullmoon
# [01:56:40 INFO]: Assigned animation id 204 to biped/skill/moonless_guard
# [01:56:40 INFO]: Assigned animation id 205 to biped/skill/moonless_guard_hit_1
# [01:56:40 INFO]: Assigned animation id 206 to biped/skill/moonless_guard_hit_2
# [01:56:40 INFO]: Assigned animation id 207 to biped/skill/moonless_guard_hit_3
# [01:56:40 INFO]: Assigned animation id 208 to biped/combat/moonless_rewinder
# [01:56:40 INFO]: Assigned animation id 209 to biped/living/solar_idle
# [01:56:40 INFO]: Assigned animation id 210 to biped/living/solar_walk
# [01:56:40 INFO]: Assigned animation id 211 to biped/living/solar_run
# [01:56:40 INFO]: Assigned animation id 212 to biped/combat/solar_auto_1
# [01:56:40 INFO]: Assigned animation id 213 to biped/combat/solar_auto_2
# [01:56:40 INFO]: Assigned animation id 214 to biped/combat/solar_auto_3
# [01:56:40 INFO]: Assigned animation id 215 to biped/combat/solar_auto_4
# [01:56:40 INFO]: Assigned animation id 216 to biped/skill/solar_auto_1_polvora
# [01:56:40 INFO]: Assigned animation id 217 to biped/skill/solar_auto_2_polvora
# [01:56:40 INFO]: Assigned animation id 218 to biped/skill/solar_auto_3_polvora
# [01:56:40 INFO]: Assigned animation id 219 to biped/skill/solar_auto_4_polvora
# [01:56:40 INFO]: Assigned animation id 220 to biped/combat/solar_quemadura
# [01:56:40 INFO]: Assigned animation id 221 to biped/combat/solar_horno
# [01:56:40 INFO]: Start animation registration of epicfight
# [01:56:40 INFO]: Assigned animation id 0 to biped/living/idle
# [01:56:40 INFO]: Assigned animation id 1 to biped/living/walk
# [01:56:40 INFO]: Assigned animation id 2 to biped/living/fly
# [01:56:40 INFO]: Assigned animation id 3 to biped/living/creative_idle
# [01:56:40 INFO]: Assigned animation id 4 to biped/living/creative_fly
# [01:56:40 INFO]: Assigned animation id 5 to biped/living/creative_fly_backward
# [01:56:40 INFO]: Assigned animation id 6 to
# [01:56:40 INFO]: Assigned animation id 7 to biped/living/hold_crossbow
# [01:56:40 INFO]: Assigned animation id 8 to biped/living/hold_map_twohand
# [01:56:40 INFO]: Assigned animation id 9 to biped/living/hold_map_offhand
# [01:56:40 INFO]: Assigned animation id 10 to biped/living/hold_map_mainhand
# [01:56:40 INFO]: Assigned animation id 11 to biped/living/hold_map_twohand_move
# [01:56:40 INFO]: Assigned animation id 12 to biped/living/hold_map_offhand_move
# [01:56:40 INFO]: Assigned animation id 13 to biped/living/hold_map_mainhand_move
# [01:56:40 INFO]: Assigned animation id 14 to biped/living/run
# [01:56:40 INFO]: Assigned animation id 15 to biped/living/sneak
# [01:56:40 INFO]: Assigned animation id 16 to biped/living/swim
# [01:56:40 INFO]: Assigned animation id 17 to biped/living/float
# [01:56:40 INFO]: Assigned animation id 18 to biped/living/kneel
# [01:56:40 INFO]: Assigned animation id 19 to biped/living/fall
# [01:56:40 INFO]: Assigned animation id 20 to biped/living/mount
# [01:56:40 INFO]: Assigned animation id 21 to biped/living/sit
# [01:56:40 INFO]: Assigned animation id 22 to biped/living/dig
# [01:56:40 INFO]: Assigned animation id 23 to biped/living/dig_offhand
# [01:56:40 INFO]: Assigned animation id 24 to
# [01:56:40 INFO]: Assigned animation id 25 to biped/combat/bow_aim_mid
# [01:56:40 INFO]: Assigned animation id 26 to biped/combat/bow_shot_mid
# [01:56:40 INFO]: Assigned animation id 27 to biped/living/drink
# [01:56:40 INFO]: Assigned animation id 28 to biped/living/drink
# [01:56:40 INFO]: Assigned animation id 29 to biped/living/drink_offhand
# [01:56:40 INFO]: Assigned animation id 30 to biped/living/eat
# [01:56:40 INFO]: Assigned animation id 31 to biped/living/eat
# [01:56:40 INFO]: Assigned animation id 32 to biped/living/eat_offhand
# [01:56:40 INFO]: Assigned animation id 33 to biped/living/spyglass
# [01:56:40 INFO]: Assigned animation id 34 to biped/living/spyglass
# [01:56:40 INFO]: Assigned animation id 35 to biped/living/spyglass_offhand
# [01:56:40 INFO]: Assigned animation id 36 to biped/combat/crossbow_aim_mid
# [01:56:40 INFO]: Assigned animation id 37 to biped/combat/crossbow_shot_mid
# [01:56:40 INFO]: Assigned animation id 38 to biped/combat/crossbow_reload
# [01:56:40 INFO]: Assigned animation id 39 to biped/living/jump
# [01:56:40 INFO]: Assigned animation id 40 to biped/living/run_spear
# [01:56:40 INFO]: Assigned animation id 41 to biped/living/shield
# [01:56:40 INFO]: Assigned animation id 42 to biped/living/shield
# [01:56:40 INFO]: Assigned animation id 43 to biped/living/shield_mirror
# [01:56:40 INFO]: Assigned animation id 44 to biped/living/hold_greatsword
# [01:56:40 INFO]: Assigned animation id 45 to biped/living/hold_uchigatana_sheath
# [01:56:40 INFO]: Assigned animation id 46 to biped/living/hold_uchigatana
# [01:56:40 INFO]: Assigned animation id 47 to biped/living/hold_tachi
# [01:56:40 INFO]: Assigned animation id 48 to biped/living/hold_longsword
# [01:56:40 INFO]: Assigned animation id 49 to biped/living/hold_spear
# [01:56:40 INFO]: Assigned animation id 50 to biped/living/hold_dual
# [01:56:40 INFO]: Assigned animation id 51 to biped/living/hold_liechtenauer
# [01:56:40 INFO]: Assigned animation id 52 to biped/living/walk_greatsword
# [01:56:40 INFO]: Assigned animation id 53 to biped/living/walk_spear
# [01:56:40 INFO]: Assigned animation id 54 to biped/living/walk_uchigatana_sheath
# [01:56:40 INFO]: Assigned animation id 55 to biped/living/walk_uchigatana
# [01:56:40 INFO]: Assigned animation id 56 to biped/living/walk_twohand
# [01:56:40 INFO]: Assigned animation id 57 to biped/living/walk_longsword
# [01:56:40 INFO]: Assigned animation id 58 to biped/living/walk_liechtenauer
# [01:56:40 INFO]: Assigned animation id 59 to biped/living/run_greatsword
# [01:56:40 INFO]: Assigned animation id 60 to biped/living/run_uchigatana
# [01:56:40 INFO]: Assigned animation id 61 to biped/living/run_uchigatana_sheath
# [01:56:40 INFO]: Assigned animation id 62 to biped/living/run_dual
# [01:56:40 INFO]: Assigned animation id 63 to biped/living/run_longsword
# [01:56:40 INFO]: Assigned animation id 64 to biped/living/uchigatana_scrap
# [01:56:40 INFO]: Assigned animation id 65 to biped/living/liechtenauer_ready
# [01:56:40 INFO]: Assigned animation id 66 to biped/combat/hit_shield
# [01:56:40 INFO]: Assigned animation id 67 to biped/combat/hit_shield
# [01:56:40 INFO]: Assigned animation id 68 to biped/combat/hit_shield_mirror
# [01:56:40 INFO]: Assigned animation id 69 to biped/living/climb
# [01:56:40 INFO]: Assigned animation id 70 to biped/living/sleep
# [01:56:40 INFO]: Assigned animation id 71 to biped/combat/javelin_aim_mid
# [01:56:40 INFO]: Assigned animation id 72 to biped/combat/javelin_throw_mid
# [01:56:40 INFO]: Assigned animation id 73 to off_highest
# [01:56:40 INFO]: Assigned animation id 74 to off_middle
# [01:56:40 INFO]: Assigned animation id 75 to zombie/idle
# [01:56:40 INFO]: Assigned animation id 76 to zombie/walk
# [01:56:40 INFO]: Assigned animation id 77 to zombie/chase
# [01:56:40 INFO]: Assigned animation id 78 to creeper/idle
# [01:56:40 INFO]: Assigned animation id 79 to creeper/walk
# [01:56:40 INFO]: Assigned animation id 80 to enderman/idle
# [01:56:40 INFO]: Assigned animation id 81 to enderman/walk
# [01:56:40 INFO]: Assigned animation id 82 to enderman/rage_idle
# [01:56:40 INFO]: Assigned animation id 83 to enderman/rage_walk
# [01:56:40 INFO]: Assigned animation id 84 to wither_skeleton/walk
# [01:56:40 INFO]: Assigned animation id 85 to wither_skeleton/chase
# [01:56:40 INFO]: Assigned animation id 86 to wither_skeleton/idle
# [01:56:40 INFO]: Assigned animation id 87 to wither_skeleton/special_spawn
# [01:56:40 INFO]: Assigned animation id 88 to spider/idle
# [01:56:40 INFO]: Assigned animation id 89 to spider/crawl
# [01:56:40 INFO]: Assigned animation id 90 to iron_golem/idle
# [01:56:40 INFO]: Assigned animation id 91 to iron_golem/walk
# [01:56:40 INFO]: Assigned animation id 92 to hoglin/idle
# [01:56:40 INFO]: Assigned animation id 93 to hoglin/walk
# [01:56:40 INFO]: Assigned animation id 94 to illager/idle
# [01:56:40 INFO]: Assigned animation id 95 to illager/walk
# [01:56:40 INFO]: Assigned animation id 96 to illager/idle_aggressive
# [01:56:40 INFO]: Assigned animation id 97 to illager/chase
# [01:56:40 INFO]: Assigned animation id 98 to illager/spellcast
# [01:56:40 INFO]: Assigned animation id 99 to ravager/idle
# [01:56:40 INFO]: Assigned animation id 100 to ravager/walk
# [01:56:40 INFO]: Assigned animation id 101 to vex/idle
# [01:56:40 INFO]: Assigned animation id 102 to vex/flip
# [01:56:40 INFO]: Assigned animation id 103 to piglin/idle
# [01:56:40 INFO]: Assigned animation id 104 to piglin/walk
# [01:56:40 INFO]: Assigned animation id 105 to piglin/zombified_idle
# [01:56:40 INFO]: Assigned animation id 106 to piglin/zombified_walk
# [01:56:40 INFO]: Assigned animation id 107 to piglin/zombified_chase
# [01:56:40 INFO]: Assigned animation id 108 to piglin/celebrate1
# [01:56:40 INFO]: Assigned animation id 109 to piglin/celebrate2
# [01:56:40 INFO]: Assigned animation id 110 to piglin/celebrate3
# [01:56:40 INFO]: Assigned animation id 111 to piglin/admire
# [01:56:40 INFO]: Assigned animation id 112 to wither/idle
# [01:56:40 INFO]: Assigned animation id 113 to biped/skill/guard_spear
# [01:56:40 INFO]: Assigned animation id 114 to biped/skill/guard_sword
# [01:56:40 INFO]: Assigned animation id 115 to biped/skill/guard_dualsword
# [01:56:40 INFO]: Assigned animation id 116 to biped/skill/guard_greatsword
# [01:56:40 INFO]: Assigned animation id 117 to biped/skill/guard_uchigatana
# [01:56:40 INFO]: Assigned animation id 118 to biped/skill/guard_longsword
# [01:56:40 INFO]: Assigned animation id 119 to biped/skill/steel_whirlwind_charging
# [01:56:40 INFO]: Assigned animation id 120 to biped/skill/roll_forward
# [01:56:40 INFO]: Assigned animation id 121 to biped/skill/roll_backward
# [01:56:40 INFO]: Assigned animation id 122 to biped/skill/step_forward
# [01:56:40 INFO]: Assigned animation id 123 to biped/skill/step_backward
# [01:56:40 INFO]: Assigned animation id 124 to biped/skill/step_left
# [01:56:40 INFO]: Assigned animation id 125 to biped/skill/step_right
# [01:56:40 INFO]: Assigned animation id 126 to biped/skill/knockdown_wakeup_left
# [01:56:40 INFO]: Assigned animation id 127 to biped/skill/knockdown_wakeup_right
# [01:56:40 INFO]: Assigned animation id 128 to biped/skill/demolition_leap_charge
# [01:56:40 INFO]: Assigned animation id 129 to biped/skill/demolition_leap
# [01:56:40 INFO]: Assigned animation id 130 to biped/skill/phantom_ascent_forward
# [01:56:40 INFO]: Assigned animation id 131 to biped/skill/phantom_ascent_backward
# [01:56:40 INFO]: Assigned animation id 132 to biped/combat/fist_auto1
# [01:56:40 INFO]: Assigned animation id 133 to biped/combat/fist_auto2
# [01:56:40 INFO]: Assigned animation id 134 to biped/combat/fist_auto3
# [01:56:40 INFO]: Assigned animation id 135 to biped/combat/fist_dash
# [01:56:40 INFO]: Assigned animation id 136 to biped/combat/sword_auto1
# [01:56:40 INFO]: Assigned animation id 137 to biped/combat/sword_auto2
# [01:56:40 INFO]: Assigned animation id 138 to biped/combat/sword_auto3
# [01:56:40 INFO]: Assigned animation id 139 to biped/combat/sword_dash
# [01:56:40 INFO]: Assigned animation id 140 to biped/combat/greatsword_auto1
# [01:56:40 INFO]: Assigned animation id 141 to biped/combat/greatsword_auto2
# [01:56:40 INFO]: Assigned animation id 142 to biped/combat/greatsword_dash
# [01:56:40 INFO]: Assigned animation id 143 to biped/combat/spear_onehand_auto
# [01:56:40 INFO]: Assigned animation id 144 to biped/combat/spear_twohand_auto1
# [01:56:40 INFO]: Assigned animation id 145 to biped/combat/spear_twohand_auto2
# [01:56:40 INFO]: Assigned animation id 146 to biped/combat/spear_dash
# [01:56:40 INFO]: Assigned animation id 147 to 136
# [01:56:40 INFO]: Assigned animation id 148 to biped/combat/sword_auto4
# [01:56:40 INFO]: Assigned animation id 149 to biped/combat/tool_dash
# [01:56:40 INFO]: Assigned animation id 150 to biped/combat/axe_dash
# [01:56:40 INFO]: Assigned animation id 151 to biped/combat/sword_dual_auto1
# [01:56:40 INFO]: Assigned animation id 152 to biped/combat/sword_dual_auto2
# [01:56:40 INFO]: Assigned animation id 153 to biped/combat/sword_dual_auto3
# [01:56:40 INFO]: Assigned animation id 154 to biped/combat/sword_dual_dash
# [01:56:40 INFO]: Assigned animation id 155 to biped/combat/uchigatana_auto1
# [01:56:40 INFO]: Assigned animation id 156 to biped/combat/uchigatana_auto2
# [01:56:40 INFO]: Assigned animation id 157 to biped/combat/uchigatana_auto3
# [01:56:40 INFO]: Assigned animation id 158 to biped/combat/uchigatana_dash
# [01:56:40 INFO]: Assigned animation id 159 to biped/combat/uchigatana_sheath_auto
# [01:56:40 INFO]: Assigned animation id 160 to biped/combat/uchigatana_sheath_dash
# [01:56:40 INFO]: Assigned animation id 161 to biped/combat/axe_auto1
# [01:56:40 INFO]: Assigned animation id 162 to biped/combat/axe_auto2
# [01:56:40 INFO]: Assigned animation id 163 to biped/combat/longsword_auto1
# [01:56:40 INFO]: Assigned animation id 164 to biped/combat/longsword_auto2
# [01:56:40 INFO]: Assigned animation id 165 to biped/combat/longsword_auto3
# [01:56:40 INFO]: Assigned animation id 166 to biped/combat/longsword_dash
# [01:56:40 INFO]: Assigned animation id 167 to biped/combat/longsword_liechtenauer_auto1
# [01:56:40 INFO]: Assigned animation id 168 to biped/combat/longsword_liechtenauer_auto2
# [01:56:40 INFO]: Assigned animation id 169 to biped/combat/longsword_liechtenauer_auto3
# [01:56:40 INFO]: Assigned animation id 170 to biped/combat/tachi_auto1
# [01:56:40 INFO]: Assigned animation id 171 to biped/combat/tachi_auto2
# [01:56:40 INFO]: Assigned animation id 172 to biped/combat/tachi_auto3
# [01:56:40 INFO]: Assigned animation id 173 to biped/combat/tachi_dash
# [01:56:40 INFO]: Assigned animation id 174 to biped/combat/dagger_auto1
# [01:56:40 INFO]: Assigned animation id 175 to biped/combat/dagger_auto2
# [01:56:40 INFO]: Assigned animation id 176 to biped/combat/dagger_auto3
# [01:56:40 INFO]: Assigned animation id 177 to biped/combat/dagger_dash
# [01:56:40 INFO]: Assigned animation id 178 to biped/combat/dagger_dual_auto1
# [01:56:40 INFO]: Assigned animation id 179 to biped/combat/dagger_dual_auto2
# [01:56:40 INFO]: Assigned animation id 180 to biped/combat/dagger_dual_auto3
# [01:56:40 INFO]: Assigned animation id 181 to biped/combat/dagger_dual_auto4
# [01:56:40 INFO]: Assigned animation id 182 to biped/combat/dagger_dual_dash
# [01:56:40 INFO]: Assigned animation id 183 to biped/combat/trident_auto1
# [01:56:40 INFO]: Assigned animation id 184 to biped/combat/trident_auto2
# [01:56:40 INFO]: Assigned animation id 185 to biped/combat/trident_auto3
# [01:56:40 INFO]: Assigned animation id 186 to biped/combat/sword_airslash
# [01:56:40 INFO]: Assigned animation id 187 to biped/combat/sword_dual_airslash
# [01:56:40 INFO]: Assigned animation id 188 to biped/combat/uchigatana_airslash
# [01:56:40 INFO]: Assigned animation id 189 to biped/combat/uchigatana_sheath_airslash
# [01:56:40 INFO]: Assigned animation id 190 to biped/combat/spear_onehand_airslash
# [01:56:40 INFO]: Assigned animation id 191 to biped/combat/spear_twohand_airslash
# [01:56:40 INFO]: Assigned animation id 192 to biped/combat/longsword_airslash
# [01:56:40 INFO]: Assigned animation id 193 to biped/combat/greatsword_airslash
# [01:56:40 INFO]: Assigned animation id 194 to biped/combat/fist_airslash
# [01:56:40 INFO]: Assigned animation id 195 to biped/combat/dagger_airslash
# [01:56:40 INFO]: Assigned animation id 196 to 187
# [01:56:40 INFO]: Assigned animation id 197 to biped/combat/axe_airslash
# [01:56:40 INFO]: Assigned animation id 198 to biped/combat/sword_mount_attack
# [01:56:40 INFO]: Assigned animation id 199 to biped/combat/spear_mount_attack
# [01:56:40 INFO]: Assigned animation id 200 to biped/combat/mob_onehand1
# [01:56:40 INFO]: Assigned animation id 201 to biped/combat/mob_onehand2
# [01:56:40 INFO]: Assigned animation id 202 to biped/combat/mob_greatsword1
# [01:56:40 INFO]: Assigned animation id 203 to biped/combat/mob_tachi_special
# [01:56:40 INFO]: Assigned animation id 204 to biped/combat/mob_spear_onehand
# [01:56:40 INFO]: Assigned animation id 205 to biped/combat/mob_spear_twohand1
# [01:56:40 INFO]: Assigned animation id 206 to biped/combat/mob_spear_twohand2
# [01:56:40 INFO]: Assigned animation id 207 to biped/combat/mob_spear_twohand3
# [01:56:40 INFO]: Assigned animation id 208 to biped/combat/mob_sword_dual1
# [01:56:40 INFO]: Assigned animation id 209 to biped/combat/mob_sword_dual2
# [01:56:40 INFO]: Assigned animation id 210 to biped/combat/mob_sword_dual3
# [01:56:40 INFO]: Assigned animation id 211 to biped/combat/mob_longsword1
# [01:56:40 INFO]: Assigned animation id 212 to biped/combat/mob_longsword2
# [01:56:40 INFO]: Assigned animation id 213 to biped/combat/mob_uchigatana1
# [01:56:40 INFO]: Assigned animation id 214 to biped/combat/mob_uchigatana2
# [01:56:40 INFO]: Assigned animation id 215 to biped/combat/mob_uchigatana3
# [01:56:40 INFO]: Assigned animation id 216 to biped/combat/mob_dagger_onehand1
# [01:56:40 INFO]: Assigned animation id 217 to biped/combat/mob_dagger_onehand2
# [01:56:40 INFO]: Assigned animation id 218 to biped/combat/mob_dagger_onehand3
# [01:56:40 INFO]: Assigned animation id 219 to biped/combat/mob_dagger_twohand1
# [01:56:40 INFO]: Assigned animation id 220 to biped/combat/mob_dagger_twohand2
# [01:56:40 INFO]: Assigned animation id 221 to biped/combat/mob_throw
# [01:56:40 INFO]: Assigned animation id 222 to biped/skill/guard_sword_hit
# [01:56:40 INFO]: Assigned animation id 223 to biped/skill/guard_sword_hit_active1
# [01:56:40 INFO]: Assigned animation id 224 to biped/skill/guard_sword_hit_active2
# [01:56:40 INFO]: Assigned animation id 225 to biped/skill/guard_sword_hit_active3
# [01:56:40 INFO]: Assigned animation id 226 to biped/skill/guard_longsword_hit_active1
# [01:56:40 INFO]: Assigned animation id 227 to biped/skill/guard_longsword_hit_active2
# [01:56:40 INFO]: Assigned animation id 228 to biped/skill/guard_dualsword_hit
# [01:56:40 INFO]: Assigned animation id 229 to biped/skill/guard_break1
# [01:56:40 INFO]: Assigned animation id 230 to biped/skill/guard_break2
# [01:56:40 INFO]: Assigned animation id 231 to biped/skill/guard_longsword_hit
# [01:56:40 INFO]: Assigned animation id 232 to biped/skill/guard_spear_hit
# [01:56:40 INFO]: Assigned animation id 233 to biped/skill/guard_greatsword_hit
# [01:56:40 INFO]: Assigned animation id 234 to biped/skill/guard_uchigatana_hit
# [01:56:40 INFO]: Assigned animation id 235 to biped/skill/greatsword_slam
# [01:56:40 INFO]: Assigned animation id 236 to biped/skill/revelation_normal
# [01:56:40 INFO]: Assigned animation id 237 to biped/skill/revelation_twohand
# [01:56:40 INFO]: Assigned animation id 238 to biped/combat/hit_short
# [01:56:40 INFO]: Assigned animation id 239 to biped/combat/hit_long
# [01:56:40 INFO]: Assigned animation id 240 to biped/combat/hit_on_mount
# [01:56:40 INFO]: Assigned animation id 241 to biped/living/landing
# [01:56:40 INFO]: Assigned animation id 242 to biped/combat/knockdown
# [01:56:40 INFO]: Assigned animation id 243 to biped/living/death
# [01:56:40 INFO]: Assigned animation id 244 to creeper/hit_short
# [01:56:40 INFO]: Assigned animation id 245 to creeper/hit_long
# [01:56:40 INFO]: Assigned animation id 246 to creeper/death
# [01:56:40 INFO]: Assigned animation id 247 to enderman/hit_short
# [01:56:40 INFO]: Assigned animation id 248 to enderman/hit_long
# [01:56:40 INFO]: Assigned animation id 249 to enderman/neutralized
# [01:56:40 INFO]: Assigned animation id 250 to enderman/convert_rage
# [01:56:40 INFO]: Assigned animation id 251 to enderman/tp_kick1
# [01:56:40 INFO]: Assigned animation id 252 to enderman/tp_kick2
# [01:56:40 INFO]: Assigned animation id 253 to enderman/rush_kick
# [01:56:40 INFO]: Assigned animation id 254 to enderman/jump_kick
# [01:56:40 INFO]: Assigned animation id 255 to enderman/knee
# [01:56:40 INFO]: Assigned animation id 256 to enderman/kick_twice
# [01:56:40 INFO]: Assigned animation id 257 to enderman/grasp
# [01:56:40 INFO]: Assigned animation id 258 to enderman/death
# [01:56:40 INFO]: Assigned animation id 259 to enderman/teleport
# [01:56:40 INFO]: Assigned animation id 260 to dragon/idle
# [01:56:40 INFO]: Assigned animation id 261 to dragon/walk
# [01:56:40 INFO]: Assigned animation id 262 to dragon/fly
# [01:56:40 INFO]: Assigned animation id 263 to dragon/death
# [01:56:40 INFO]: Assigned animation id 264 to dragon/ground_to_fly
# [01:56:40 INFO]: Assigned animation id 265 to dragon/fly_to_ground
# [01:56:40 INFO]: Assigned animation id 266 to dragon/attack1
# [01:56:40 INFO]: Assigned animation id 267 to dragon/attack2
# [01:56:40 INFO]: Assigned animation id 268 to dragon/attack3
# [01:56:40 INFO]: Assigned animation id 269 to dragon/attack4
# [01:56:40 INFO]: Assigned animation id 270 to dragon/attack4_recovery
# [01:56:40 INFO]: Assigned animation id 271 to dragon/fireball
# [01:56:40 INFO]: Assigned animation id 272 to dragon/airstrike
# [01:56:40 INFO]: Assigned animation id 273 to dragon/backjump_prepare
# [01:56:40 INFO]: Assigned animation id 274 to dragon/backjump_move
# [01:56:40 INFO]: Assigned animation id 275 to dragon/backjump_recovery
# [01:56:40 INFO]: Assigned animation id 276 to dragon/crystal_link
# [01:56:40 INFO]: Assigned animation id 277 to dragon/neutralized
# [01:56:40 INFO]: Assigned animation id 278 to dragon/neutralized_recovery
# ...
# 	at net.minecraft.util.thread.BlockableEventLoop.m_7245_(BlockableEventLoop.java:130) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.level.ServerChunkCache$MainThreadExecutor.m_7245_(ServerChunkCache.java:593) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.util.thread.BlockableEventLoop.m_18701_(BlockableEventLoop.java:139) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.level.ServerChunkCache.getChunkBlocking(ServerChunkCache.java:1310) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.level.ServerChunkCache.m_7587_(ServerChunkCache.java:1206) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.Level.m_6522_(Level.java:285) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.Level.m_6325_(Level.java:2267) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.Level.m_8055_(Level.java:2757) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.navigation.GroundPathNavigation.m_7864_(GroundPathNavigation.java:43) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.navigation.PathNavigation.m_26569_(PathNavigation.java:86) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.level.ServerLevel.m_7260_(ServerLevel.java:1136) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.Level.markAndNotifyBlock(Level.java:376) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.Level.m_6933_(Level.java:356) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.Level.m_7731_(Level.java:294) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.block.DoorBlock.m_153165_(DoorBlock.java:177) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.behavior.InteractWithDoor.m_258036_(InteractWithDoor.java:123) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.behavior.InteractWithDoor.m_257200_(InteractWithDoor.java:90) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at java.util.Optional.ifPresent(Optional.java:178) ~[?:?]
# 	at net.minecraft.world.entity.ai.behavior.InteractWithDoor.m_257204_(InteractWithDoor.java:89) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.behavior.declarative.BehaviorBuilder$1.m_257808_(BehaviorBuilder.java:53) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.behavior.OneShot.m_22554_(OneShot.java:20) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.Brain.m_21957_(Brain.java:655) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.ai.Brain.m_21865_(Brain.java:389) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.npc.Villager.m_8024_(Villager.java:226) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.entity.npc.Villager.inactiveTick(Villager.java:216) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.level.ServerLevel.m_8647_(ServerLevel.java:790) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.Level.m_46653_(Level.java:628) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.level.ServerLevel.m_184063_(ServerLevel.java:426) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.world.level.entity.EntityTickList.m_156910_(EntityTickList.java:54) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.level.ServerLevel.m_8793_(ServerLevel.java:406) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.MinecraftServer.m_5703_(MinecraftServer.java:1158) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_5703_(DedicatedServer.java:344) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.MinecraftServer.m_5705_(MinecraftServer.java:1074) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:904) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:281) ~[server-1.20.1-20230612.114412-srg.jar%23278!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [02:20:28 INFO]: <AshOficialMC> en una cosa toda rara
# [02:20:49 INFO]: Nachus_GC issued server command: /gamemode creative
# [02:20:52 INFO]: AshOficialMC has reached the goal [Strengthened by Fire]
# [02:20:59 INFO]: Nachus_GC issued server command: /afk
# [02:21:55 INFO]: xXDash_RedXx has made the advancement [advancements.alexsmobs.root.title]
# [02:22:18 INFO]: AshOficialMC issued server command: /gamemode spectator
# [02:22:36 INFO]: AshOficialMC issued server command: /gamemode survival
# [02:22:44 INFO]: <Nachus_GC> Esto es del nuevo datapack Ash?
# [02:23:03 INFO]: xXDash_RedXx lost connection: Disconnected
# [02:23:03 INFO]: xXDash_RedXx left the game
# [02:23:05 INFO]: <AshOficialMC> idk
# [02:23:41 INFO]: Nachus_GC issued server command: /tp Nachus_GC AshOficialMC
# [02:23:54 INFO]: <Nachus_GC> waos
# [02:23:57 INFO]: AshOficialMC has made the advancement [Diamonds!]
# [02:24:07 INFO]: <Nachus_GC> Mi casa
# [02:24:15 INFO]: <Nachus_GC> Deah
# [02:24:28 INFO]: Nachus_GC has made the advancement [Acquire Hardware]
# [02:25:30 INFO]: <Nachus_GC> AAAAAAAH
# [02:25:32 INFO]: AshOficialMC issued server command: /gamemode creative
# [02:25:41 INFO]: <Nachus_GC> COMO Q ESQUELETOS FULL DIAMANTE!!??
# [02:25:43 INFO]: AshOficialMC issued server command: /gamemode survival
# [02:25:54 INFO]: <AshOficialMC> una taberna
# [02:26:06 INFO]: <AshOficialMC> encontre petroleo
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [02:26:27 INFO]: <Nachus_GC> *Musica yankie de fondo*
# [02:26:37 INFO]: <AshOficialMC> XD
# [02:26:40 INFO]: <Nachus_GC> XD
# [02:26:57 INFO]: <Nachus_GC> weon
# [02:27:09 INFO]: <Nachus_GC> Hay un creeper cargado encima de un ravager
# [02:27:16 INFO]: <Nachus_GC> q demonios es este sitio
# [02:27:22 INFO]: Nachus_GC has made the advancement [Diamonds!]
# [02:27:43 INFO]: Named entity Zombie['Gearling'/6570, l='ServerLevel[world]', x=90.08, y=212.41, z=131.37] died: Gearling was slain by Nachus_GC
# [02:27:43 INFO]: <AshOficialMC> nose pero esta roto lo que hay
# [02:27:48 INFO]: Named entity Zombie['Gearling'/6811, l='ServerLevel[world]', x=91.85, y=212.00, z=134.05] died: Gearling was slain by Nachus_GC
# [02:27:53 INFO]: <Nachus_GC> si xd
# [02:27:58 INFO]: <AshOficialMC> me saque 10 manzanas de oro
# [02:28:04 INFO]: <AshOficialMC> y 12 diamantes
# [02:28:35 INFO]: Named entity Zombie['Gearling'/6943, l='ServerLevel[world]', x=19.13, y=212.00, z=77.15] died: Gearling was slain by Nachus_GC
# [02:28:38 INFO]: Named entity Zombie['Gearling'/6948, l='ServerLevel[world]', x=17.04, y=212.00, z=80.43] died: Gearling was slain by Nachus_GC
# [02:28:39 INFO]: Named entity Zombie['Gearling'/6963, l='ServerLevel[world]', x=16.39, y=212.00, z=83.09] died: Gearling was slain by Nachus_GC
# [02:28:41 INFO]: Named entity Zombie['Gearling'/6980, l='ServerLevel[world]', x=15.56, y=213.00, z=81.00] died: Gearling was slain by Nachus_GC
# [02:28:45 INFO]: Named entity Zombie['Gearling'/6994, l='ServerLevel[world]', x=18.46, y=212.00, z=79.76] died: Gearling was slain by Nachus_GC
# [02:28:48 INFO]: Named entity Zombie['Gearling'/6991, l='ServerLevel[world]', x=13.49, y=212.75, z=82.85] died: Gearling was slain by Nachus_GC
# [02:28:51 INFO]: Named entity Zombie['Gearling'/6947, l='ServerLevel[world]', x=8.10, y=213.02, z=83.06] died: Gearling was slain by Nachus_GC
# [02:28:54 INFO]: Named entity Zombie['Gearling'/6944, l='ServerLevel[world]', x=3.68, y=212.00, z=82.55] died: Gearling was slain by Nachus_GC
# [02:29:08 INFO]: AshOficialMC issued server command: /gamemode creative
# [02:29:15 INFO]: AshOficialMC issued server command: /gamemode survival
# [02:29:20 INFO]: Nachus_GC has made the advancement [Suit Up]
# [02:29:27 INFO]: <AshOficialMC> UYY
# [02:30:21 INFO]: <AshOficialMC> a
# [02:31:06 INFO]: <AshOficialMC> parece una ciudadela
# [02:31:14 INFO]: <Nachus_GC> EL QUE TENGA MIEDO A MORIR QUE NO NAZCAAAAAAAAAAAAA!
# [02:31:30 INFO]: <Nachus_GC> uff
# [02:32:35 INFO]: <Nachus_GC> cocodrilo
# [02:32:55 INFO]: <AshOficialMC> BRO
# [02:33:04 INFO]: <Nachus_GC> QUE PASA BEO
# [02:33:19 INFO]: AshOficialMC has made the advancement [Acquire Hardware]
# [02:33:20 INFO]: AshOficialMC was slain by Gearling
# [02:33:26 INFO]: <AshOficialMC> NOOO
# [02:33:26 INFO]: <Nachus_GC> xd
# [02:33:31 INFO]: <Nachus_GC> Te mataron los peques
# [02:33:45 INFO]: AshOficialMC issued server command: /tp AshOficialMC -71.5 212 129.5
# [02:34:21 INFO]: Named entity Zombie['Gearling'/8864, l='ServerLevel[world]', x=-83.68, y=134.00, z=128.96] died: Gearling fell from a high place
# [02:34:21 INFO]: Named entity Zombie['Gearling'/8877, l='ServerLevel[world]', x=-83.27, y=134.00, z=128.98] died: Gearling fell from a high place
# [02:34:25 INFO]: <AshOficialMC> casi caigo al vacio
# [02:35:10 INFO]: AshOficialMC was slain by Gearling
# [02:35:16 INFO]: AshOficialMC issued server command: /tp AshOficialMC -71.5 212 129.5
# [02:35:31 INFO]: Named entity Zombie['Gearling'/8763, l='ServerLevel[world]', x=-84.34, y=133.00, z=128.56] died: Gearling fell from a high place
# [02:35:31 INFO]: AshOficialMC issued server command: /gamemode creative
# [02:35:31 INFO]: Named entity Zombie['Gearling'/9171, l='ServerLevel[world]', x=-83.50, y=134.00, z=130.23] died: Gearling fell from a high place
# [02:35:43 INFO]: Named entity Zombie['Gearling'/9311, l='ServerLevel[world]', x=-81.60, y=135.00, z=131.08] died: Gearling fell from a high place
# [02:35:46 INFO]: Named entity Zombie['Gearling'/8908, l='ServerLevel[world]', x=-87.21, y=128.00, z=131.71] died: Gearling fell from a high place
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [02:36:28 INFO]: AshOficialMC issued server command: /gamemode survival
# [02:36:40 INFO]: AshOficialMC was slain by Skeleton
# [02:36:46 INFO]: AshOficialMC issued server command: /gamemode creative
# [02:36:49 INFO]: AshOficialMC issued server command: /tp AshOficialMC -82.5 212 179.5
# [02:36:59 INFO]: <AshOficialMC> me papiaron
# [02:37:08 INFO]: Nachus_GC has made the advancement [Cover Me with Diamonds]
# [02:37:16 INFO]: <Nachus_GC> q rico
# [02:38:21 INFO]: AshOficialMC has made the advancement [Monster Hunter]
# [02:38:26 INFO]: <AshOficialMC> toma
# [02:38:27 INFO]: AshOficialMC issued server command: /gamemode survival
# [02:40:14 INFO]: <AshOficialMC> tas vivo?
# [02:40:17 INFO]: <Nachus_GC> a medio cora bldo
# [02:40:22 INFO]: <AshOficialMC> yo wn
# [02:40:28 INFO]: <AshOficialMC> casi me cuesta la vida esto
# [02:40:39 INFO]: AshOficialMC has made the advancement [Cover Me with Diamonds]
# [02:41:32 INFO]: AshOficialMC issued server command: /gamemode creative
# [02:41:59 INFO]: AshOficialMC issued server command: /gamemode adventure
# [02:42:02 INFO]: AshOficialMC issued server command: /gamemode creative
# [02:42:10 INFO]: AshOficialMC issued server command: /gamemode survival
# [02:42:54 INFO]: <AshOficialMC> Estoy listo
# [02:42:57 INFO]: <AshOficialMC> para morir
# [02:43:13 INFO]: Nachus_GC has made the advancement [Sneak 100]
# [02:43:32 INFO]: <Nachus_GC> estoy en la punta wn
# [02:43:33 INFO]: <AshOficialMC> a
# [02:44:45 INFO]: <Nachus_GC> bruh
# [02:44:53 INFO]: <AshOficialMC> de dia no atacan
# [02:44:59 INFO]: <AshOficialMC> segun yo
# [02:45:11 INFO]: <AshOficialMC> me robo todo
# [02:45:22 INFO]: <Nachus_GC> x2
# [02:45:55 INFO]: Named entity Zombie['Gearling'/10982, l='ServerLevel[world]', x=-13.85, y=281.17, z=83.54] died: Gearling was slain by Nachus_GC
# [02:45:58 INFO]: Named entity Zombie['Gearling'/10989, l='ServerLevel[world]', x=-14.88, y=280.52, z=83.35] died: Gearling was slain by Nachus_GC
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [02:46:32 INFO]: <AshOficialMC> bro vuelve a donde stabamos
# [02:46:34 INFO]: <Nachus_GC> whaaa
# [02:46:51 INFO]: <Nachus_GC> bldo me dieron un alma demoniaca
# [02:46:56 INFO]: <AshOficialMC> q
# [02:46:59 INFO]: <Nachus_GC> asies
# [02:47:01 INFO]: AshOficialMC issued server command: /invsee Nachus_GC
# [02:47:07 INFO]: <Nachus_GC> una re fumada
# [02:47:11 INFO]: <Nachus_GC> q no hace nada XD
# [02:47:15 INFO]: <AshOficialMC> epico
# [02:48:17 INFO]: Named entity Zombie['Gearling'/11240, l='ServerLevel[world]', x=-74.13, y=212.00, z=130.48] died: Gearling went off with a bang
# [02:48:28 INFO]: <Nachus_GC> ash donde andai
# [02:48:40 INFO]: <AshOficialMC> en lo ultimo de arriba
# [02:48:44 INFO]: <Nachus_GC> uh
# [02:48:44 INFO]: <AshOficialMC> dodne me viste por ultima vez
# [02:48:51 INFO]: <Nachus_GC> ah ok
# [02:48:59 INFO]: <Nachus_GC> yo ya estoy bajando
# [02:49:13 INFO]: AshOficialMC was slain by Gearling
# [02:49:16 INFO]: <Nachus_GC> corre negro
# [02:49:21 INFO]: <Nachus_GC> XD
# [02:49:34 INFO]: <AshOficialMC> que
# [02:49:36 INFO]: <AshOficialMC> me dio lag
# [02:49:40 INFO]: AshOficialMC issued server command: /gamemode creative
# [02:49:42 INFO]: <Nachus_GC> Si vi
# [02:49:42 INFO]: AshOficialMC issued server command: /tp AshOficialMC -34.5 213 130.5
# [02:50:03 INFO]: Nachus_GC has made the advancement [Take Aim]
# [02:50:12 INFO]: AshOficialMC issued server command: /gamemode survival
# [02:50:21 INFO]: Named entity Zombie['Gearling'/11330, l='ServerLevel[world]', x=-83.48, y=134.00, z=129.46] died: Gearling fell from a high place
# [02:50:26 INFO]: <AshOficialMC> UY
# [02:50:27 INFO]: <Nachus_GC> nos vemos abajo broh
# [02:50:28 INFO]: Named entity Zombie['Gearling'/11328, l='ServerLevel[world]', x=-83.16, y=134.00, z=129.24] died: Gearling fell from a high place
# [02:50:52 INFO]: <AshOficialMC> bno bro demo irme
# [02:51:00 INFO]: <Nachus_GC> uh bueno
# [02:51:09 INFO]: <AshOficialMC> toca apagar el serv, jugamos mañana
# [02:51:17 INFO]: <Nachus_GC> bien broh
# [02:51:37 INFO]: <AshOficialMC> srry
# [02:51:39 INFO]: AshOficialMC lost connection: Disconnected
# [02:51:39 INFO]: AshOficialMC left the game
# [02:51:53 INFO]: Nachus_GC issued server command: /gamemode spectator
# [02:51:58 INFO]: Nachus_GC issued server command: /gamemode survival
# [02:52:03 INFO]: Nachus_GC lost connection: Disconnected
# [02:52:03 INFO]: Nachus_GC left the game
# >
